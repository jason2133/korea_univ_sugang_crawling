# %%
import urllib.request as req
from bs4 import BeautifulSoup
import pandas as pd

# %%
your_major = "STAT" # 전공과목영문코드 입력
cour_num = []
name = []
cour_time = []
cour_prof = []

# %%
# !nvidia-smi
# Out:
# Tue May 10 15:37:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
for number in range (100, 500):
    url = "https://infodepot.korea.ac.kr/lecture1/lecsubjectPlanView.jsp?year=2022&term=1S&grad_cd=0136&col_cd=9999&dept_cd=4653&cour_cd=" + your_major + str(number) + "&cour_cls=00&"
    html = req.urlopen(url)
    doc = BeautifulSoup(html,"html.parser")
    temp_title = doc.h3.string
    if len(temp_title) == 19:
        for number2 in range (1, 10):
            url2 = url[:-2] + str(number2) + "&"
            html = req.urlopen(url2)
            doc = BeautifulSoup(html,"html.parser")
            temp_title = doc.h3.string
            if len(temp_title) == 19:
                break
            else:
                title = temp_title.split("[")[1].split("]")[0]
                try:
                    time = doc.find(class_="tbl_view").tbody.tr.td.string.splitlines()
                    time = " ".join(time)
                    prof = doc.find(class_="tbl_view").next_sibling.next_sibling.next_sibling.next_sibling.tbody.tr.td.string
                except:
                    time = None
                    prof = None
                cour_time.append(time)
                cour_prof.append(prof)
                cour_number = your_major + str(number) + "-0" + str(number2)
                cour_num.append(cour_number)
                name.append(title)
                print(f"{cour_number} 완료")
    else:
        title = temp_title.split("[")[1].split("]")[0]
        try:
            time = doc.find(class_="tbl_view").tbody.tr.td.string.splitlines()
            time = " ".join(time)
            prof = doc.find(class_="tbl_view").next_sibling.next_sibling.next_sibling.next_sibling.tbody.tr.td.string
        except:
            time = None
            prof = None
        cour_time.append(time)
        cour_prof.append(prof)
        cour_number = your_major + str(number) + "-00"
        cour_num.append(cour_number)
        name.append(title)
        print(f"{cour_number} 완료")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#
# /usr/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1280         """Send a complete request to the server."""
# -> 1281         self._send_request(method, url, body, headers, encode_chunked)
#    1282
#
# /usr/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1326             body = _encode(body, 'body')
# -> 1327         self.endheaders(body, encode_chunked=encode_chunked)
#    1328
#
# ...

# %%
your_major = "BUSS" # 전공과목영문코드 입력
cour_num = []
name = []
cour_time = []
cour_prof = []

# %%
for number in range (100, 500):
    url = "https://infodepot.korea.ac.kr/lecture1/lecsubjectPlanView.jsp?year=2022&term=1S&grad_cd=0136&col_cd=9999&dept_cd=4653&cour_cd=" + your_major + str(number) + "&cour_cls=00&"
    html = req.urlopen(url)
    doc = BeautifulSoup(html,"html.parser")
    temp_title = doc.h3.string
    if len(temp_title) == 19:
        for number2 in range (1, 10):
            url2 = url[:-2] + str(number2) + "&"
            html = req.urlopen(url2)
            doc = BeautifulSoup(html,"html.parser")
            temp_title = doc.h3.string
            if len(temp_title) == 19:
                break
            else:
                title = temp_title.split("[")[1].split("]")[0]
                try:
                    time = doc.find(class_="tbl_view").tbody.tr.td.string.splitlines()
                    time = " ".join(time)
                    prof = doc.find(class_="tbl_view").next_sibling.next_sibling.next_sibling.next_sibling.tbody.tr.td.string
                except:
                    time = None
                    prof = None
                cour_time.append(time)
                cour_prof.append(prof)
                cour_number = your_major + str(number) + "-0" + str(number2)
                cour_num.append(cour_number)
                name.append(title)
                print(f"{cour_number} 완료")
    else:
        title = temp_title.split("[")[1].split("]")[0]
        try:
            time = doc.find(class_="tbl_view").tbody.tr.td.string.splitlines()
            time = " ".join(time)
            prof = doc.find(class_="tbl_view").next_sibling.next_sibling.next_sibling.next_sibling.tbody.tr.td.string
        except:
            time = None
            prof = None
        cour_time.append(time)
        cour_prof.append(prof)
        cour_number = your_major + str(number) + "-00"
        cour_num.append(cour_number)
        name.append(title)
        print(f"{cour_number} 완료")
# Out:
# BUSS152-00 완료
# BUSS205-00 완료
# BUSS207-00 완료
# BUSS213-00 완료
# BUSS215-00 완료
# BUSS252-00 완료
# BUSS254-00 완료
# BUSS311-00 완료
# BUSS313-00 완료
# BUSS402-00 완료

# %%
cour_table = pd.DataFrame({"학수번호" : cour_num, "강의명" : name, "시간" : cour_time, "교수명" : cour_prof})
cour_table
# Out:
#          학수번호            강의명  \
# 0  BUSS152-00     회계학원리(영강)
# 1  BUSS205-00         마케팅원론
# 2  BUSS207-00      재무관리(영강)
# 3  BUSS213-00     중급회계I(영강)
# 4  BUSS215-00   경영정보시스템(영강)
# 5  BUSS252-00    마케팅조사론(영강)
# 6  BUSS254-00           투자론
# 7  BUSS311-00         조직행동론
# 8  BUSS313-00     국제경영론(영강)
# 9  BUSS402-00      경영전략(영강)
#
#                                                   시간   교수명
# 0  월(1-3) 현차관 B205호 화(1-3) 현차관 B205호 수(1-3) 현차관 B...  None
# 1  월(5-7) 현차관 303호 화(5-7) 현차관 303호 수(5-7) 현차관 303...  None
# 2  월(5-7) 현차관 B204호 화(5-7) 현차관 B204호 수(5-7) 현차관 B...  None
# 3  월(5-7) 현차관 B205호 화(5-7) 현차관 B205호 수(5-7) 현차관 B...  None
# 4  월(1-3) 현차관 303호 화(1-3) 현차관 303호 수(1-3) 현차관 303...  None
# 5  월(1-3) 현차관412 화(1-3) 현차관412 수(1-3) 현차관412 목(1-...  None
# 6  월(1-3) 현차관403 화(1-3) 현차관403 수(1-3) 현차관403 목(1-...   정재웅
# 7  월(5-7) 현차관403 화(5-7) 현차관403 수(5-7) 현차관403 목(5-...  None
# 8  월(5-7) 현차관412 화(5-7) 현차관412 수(5-7) 현차관412 목(5-...  None
# ...

# %%
cour_table_2 = cour_table.drop(cour_table[cour_table["강의명"] == " "].index)
cour_table_2.to_excel(f"22_1_Summer_{your_major}.xlsx")

# %%
your_major = "STAT" # 전공과목영문코드 입력
cour_num = []
name = []
cour_time = []
cour_prof = []

# %%
for number in range (100, 500):
    url = "https://infodepot.korea.ac.kr/lecture1/lecsubjectPlanView.jsp?year=2022&term=1S&grad_cd=0136&col_cd=9999&dept_cd=4653&cour_cd=" + your_major + str(number) + "&cour_cls=00&"
    html = req.urlopen(url)
    doc = BeautifulSoup(html,"html.parser")
    temp_title = doc.h3.string
    if len(temp_title) == 19:
        for number2 in range (1, 10):
            url2 = url[:-2] + str(number2) + "&"
            html = req.urlopen(url2)
            doc = BeautifulSoup(html,"html.parser")
            temp_title = doc.h3.string
            if len(temp_title) == 19:
                break
            else:
                title = temp_title.split("[")[1].split("]")[0]
                try:
                    time = doc.find(class_="tbl_view").tbody.tr.td.string.splitlines()
                    time = " ".join(time)
                    prof = doc.find(class_="tbl_view").next_sibling.next_sibling.next_sibling.next_sibling.tbody.tr.td.string
                except:
                    time = None
                    prof = None
                cour_time.append(time)
                cour_prof.append(prof)
                cour_number = your_major + str(number) + "-0" + str(number2)
                cour_num.append(cour_number)
                name.append(title)
                print(f"{cour_number} 완료")
    else:
        title = temp_title.split("[")[1].split("]")[0]
        try:
            time = doc.find(class_="tbl_view").tbody.tr.td.string.splitlines()
            time = " ".join(time)
            prof = doc.find(class_="tbl_view").next_sibling.next_sibling.next_sibling.next_sibling.tbody.tr.td.string
        except:
            time = None
            prof = None
        cour_time.append(time)
        cour_prof.append(prof)
        cour_number = your_major + str(number) + "-00"
        cour_num.append(cour_number)
        name.append(title)
        print(f"{cour_number} 완료")
# Out:
# STAT170-00 완료
# STAT180-00 완료
# STAT342-00 완료

# %%
cour_table = pd.DataFrame({"학수번호" : cour_num, "강의명" : name, "시간" : cour_time, "교수명" : cour_prof})
cour_table
# Out:
#          학수번호          강의명                               시간   교수명
# 0  STAT170-00       기초통계학   월(1-3)  화(1-3)  수(1-3)  목(1-3)    백정민
# 1  STAT180-00   통계계산소프트웨어   월(1-3)  화(1-3)  수(1-3)  목(1-3)   오찬욱
# 2  STAT342-00        회귀분석   월(5-7)  화(5-7)  수(5-7)  목(5-7)   None

# %%
cour_table_2 = cour_table.drop(cour_table[cour_table["강의명"] == " "].index)
cour_table_2.to_excel(f"22_1_Summer_{your_major}.xlsx")
